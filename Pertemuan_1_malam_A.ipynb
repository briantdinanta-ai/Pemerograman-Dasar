# %% [markdown]
# <a href="https://colab.research.google.com/github/briantdinanta-ai/Pemerograman-Dasar/blob/main/Pertemuan_1_malam_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "andi"
umur = 26
jurusan = "RPE"
semester = 3
matakuliah = 'pemograman dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)


nama = "Aldio"
umur = "32"
jurusan = "RPE"
semester = 3
matakuliah = 'pemograman dasar'
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# andi
# 26
# RPE
# 3
# pemograman dasar
# False
# Aldio
# 32
# RPE
# 3
# pemograman dasar
# False

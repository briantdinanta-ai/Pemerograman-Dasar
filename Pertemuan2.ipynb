# %% [markdown]
# <a href="https://colab.research.google.com/github/briantdinanta-ai/Pemerograman-Dasar/blob/main/Pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1
tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"

print(tegangan)
print(arus)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
# Jawaban Latihan 2
jumlah_resistor = 25          # int
nilai_kapasitor = 4.7         # float
komponen_terpasang = True     # bool
nama_komponen = "Resistor 10k" # str

print(jumlah_resistor, type(jumlah_resistor))
print(nilai_kapasitor, type(nilai_kapasitor))
print(komponen_terpasang, type(komponen_terpasang))
print(nama_komponen, type(nama_komponen))
# Out:
# 25 <class 'int'>
# 4.7 <class 'float'>
# True <class 'bool'>
# Resistor 10k <class 'str'>

# %%
# Jawaban Latihan 3
nama_unit = "PLTS Nunukan"     # string, karena berupa teks
jumlah_panel = 240             # int, jumlah barang selalu bulat
tegangan_keluaran = 48.5       # float, karena ada koma/desimal
sedang_beroperasi = True       # bool, karena cuma benar/salah

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
# Jawaban Latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# a) cetak pembacaan pertama dan terakhir
print("Pembacaan pertama:", tegangan_harian[0])
print("Pembacaan terakhir:", tegangan_harian[-1])

# b) tambahkan pembacaan baru
tegangan_harian.append(222.0)
print("Setelah ditambah:", tegangan_harian)

# c) jumlah total data
print("Jumlah data:", len(tegangan_harian))
# Out:
# Pembacaan pertama: 217.5
# Pembacaan terakhir: 216.9
# Setelah ditambah: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# Jumlah data: 7

# %%
# Jawaban Latihan 5
motor = {
    "nama": "Motor Induksi 3 Fasa",
    "daya_kW": 5.5,
    "tegangan_V": 380,
    "rpm": 1450
}

# cetak salah satu nilai lewat key
print("RPM awal:", motor["rpm"])

# ubah nilai rpm
motor["rpm"] = 1470

# cetak ulang seluruh dictionary
print(motor)
# Out:
# RPM awal: 1450
# {'nama': 'Motor Induksi 3 Fasa', 'daya_kW': 5.5, 'tegangan_V': 380, 'rpm': 1470}

# %%
# Jawaban Latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"}
]

# cetak nama unit kedua
print("Unit kedua:", pembangkit[1]["nama"])

# ubah status salah satu unit
pembangkit[2]["status"] = "operasi"

# tambahkan satu unit baru
pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 120, "status": "operasi"})

# cetak seluruh data
for unit in pembangkit:
    print(unit)
# Out:
# Unit kedua: Unit-2
# {'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}
# {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}
